# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from pathlib import Path

# %%
# %cd /gdrive/My Drive/polimi/artificialneuraldeep
# Out:
# /gdrive/My Drive/polimi/artificialneuraldeep

# %%
ls -l
# Out:
# total 4678
# -rw------- 1 root root 2721340 Nov 17 19:10 '2) Hold Out, Early Stopping and Cross Validation.ipynb'
# -rw------- 1 root root   16168 Sep 29 16:34  AN2DL.ipynb
# -rw------- 1 root root  433019 Oct  4 18:23  AND2LREDNEURONAL1.ipynb
# -rw------- 1 root root  965537 Nov 16 13:25 'Copia de 2) Skeleton.ipynb'
# -rw------- 1 root root  125042 Nov 15 16:54 'Copia de 3) Convolutional Neural Network (Skeleton).ipynb'
# -rw------- 1 root root   68399 Oct 27 16:13 'Copia de 3) Convolution (Skeleton).ipynb'
# drwx------ 2 root root    4096 Oct 19 12:15  DefaultModel/
# drwx------ 2 root root    4096 Nov  3 16:35  Exercise_4/
# -rw------- 1 root root   16733 Oct 19 12:19  model.png
# -rw------- 1 root root   64876 Oct 27 15:35  picture.jpg
# -rw------- 1 root root    1431 Dec 16 13:49  Untitled0.ipynb
# -rw------- 1 root root  366717 Oct 13 15:25  winequality.csv

# %%
p = Path('.')

# %%
[x for x in p.iterdir() if x.is_dir()]
# Out:
# [PosixPath('DefaultModel'), PosixPath('Exercise_4')]

# %%
list(p.glob('*'))
# Out:
# [PosixPath('AN2DL.ipynb'),
#  PosixPath('AND2LREDNEURONAL1.ipynb'),
#  PosixPath('winequality.csv'),
#  PosixPath('DefaultModel'),
#  PosixPath('model.png'),
#  PosixPath('picture.jpg'),
#  PosixPath('Copia de 3) Convolution (Skeleton).ipynb'),
#  PosixPath('Exercise_4'),
#  PosixPath('Copia de 3) Convolutional Neural Network (Skeleton).ipynb'),
#  PosixPath('Copia de 2) Skeleton.ipynb'),
#  PosixPath('2) Hold Out, Early Stopping and Cross Validation.ipynb'),
#  PosixPath('Untitled0.ipynb')]
